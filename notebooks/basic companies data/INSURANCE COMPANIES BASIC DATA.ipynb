# %%
from __future__ import annotations

import base64
import getpass
import logging
import os
import time  # Add time module import
from datetime import datetime, timedelta
from pathlib import Path
from typing import Optional, Dict, List, Any
from collections import deque

import pandas as pd
import requests
from pydantic import BaseModel, Field
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry

# Configuration
class Config:
    # API Settings
    BASE_URL = "https://api.companieshouse.gov.uk"
    MAX_RESULTS = 1000
    ITEMS_PER_PAGE = 100
    
    # Rate Limiting
    MAX_REQUESTS = 590
    TIME_WINDOW = 300  # seconds
    
    # SIC Codes for Insurance Companies
    INSURANCE_SIC_CODES = ['651', '652']
    
    # Search Terms
    SEARCH_TERMS = [
        "insurance company",
        "insurance limited",
        "insurance ltd",
        "insurance plc",
        "assurance company",
        "assurance limited",
        "assurance ltd",
        "assurance plc"
    ]
    
    # Output Directory
    OUTPUT_DIR = Path("insurance_companies_data")

# Data Models
class RegisteredOffice(BaseModel):
    address_line_1: Optional[str] = None
    address_line_2: Optional[str] = None
    locality: Optional[str] = None
    postal_code: Optional[str] = None

class CompanyData(BaseModel):
    company_number: str
    company_name: str
    company_status: str
    date_of_creation: str
    registered_office_address: str
    sic_codes: str

class APIResponse(BaseModel):
    items: List[Dict[str, Any]]
    total_results: Optional[int] = None
    page_number: Optional[int] = None
    kind: Optional[str] = None

# Set up logging
def setup_logging() -> logging.Logger:
    logger = logging.getLogger(__name__)
    logger.propagate = False
    logger.setLevel(logging.INFO)
    logger.handlers.clear()
    
    handler = logging.StreamHandler()
    formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
    handler.setFormatter(formatter)
    logger.addHandler(handler)
    
    return logger

class RateLimiter:
    
    import time

    """Implements rate limiting for API requests."""
    
    def __init__(self, max_requests: int, time_window: int, logger: logging.Logger):
        self.max_requests = max_requests
        self.time_window = time_window
        self.logger = logger  # Add logger as instance variable
        self.requests: deque = deque()
    
    def can_make_request(self) -> bool:
        now = datetime.utcnow()
        while self.requests and self.requests[0] < now - timedelta(seconds=self.time_window):
            self.requests.popleft()
        
        if len(self.requests) < self.max_requests:
            self.requests.append(now)
            return True
        return False
    
    def wait_if_needed(self) -> int:
        current_requests = len(self.requests)
        if current_requests >= self.max_requests:
            self.logger.info(f"Rate limit reached. Current requests in window: {current_requests}")
        
        while not self.can_make_request():
            self.logger.debug(f"Waiting for rate limit. Current requests: {len(self.requests)}")
            time.sleep(1)
        
        current_requests = len(self.requests)
        self.logger.debug(f"Request allowed. Current requests in window: {current_requests}")
        return current_requests

class CompaniesHouseAPI:
    """Handler for Companies House API interactions."""
    
    def __init__(self, api_key: str, logger: logging.Logger):
        self.api_key = api_key
        self.logger = logger
        # Pass logger to RateLimiter
        self.rate_limiter = RateLimiter(Config.MAX_REQUESTS, Config.TIME_WINDOW, logger)
        self.session = self._create_session()
        
        # Create base64 encoded authentication
        auth = base64.b64encode(f"{api_key}:".encode('ascii')).decode('ascii')
        self.headers = {
            'Authorization': f'Basic {auth}',
            'Accept': 'application/json'
        }
    
    @staticmethod
    def _create_session() -> requests.Session:
        """Create a session with retry strategy."""
        session = requests.Session()
        retry_strategy = Retry(
            total=3,
            backoff_factor=1,
            status_forcelist=[429, 500, 502, 503, 504]
        )
        adapter = HTTPAdapter(max_retries=retry_strategy)
        session.mount("https://", adapter)
        return session
    
    def search_companies(self, search_term: str, start_index: int = 0) -> Optional[APIResponse]:
        """Search for companies using the Companies House API."""
        params = {
            'q': search_term,
            'items_per_page': Config.ITEMS_PER_PAGE,
            'start_index': start_index,
            'company_status': 'active'
        }
        
        try:
            self.rate_limiter.wait_if_needed()
            
            if start_index >= Config.MAX_RESULTS:
                self.logger.info(f"Reached maximum results limit ({Config.MAX_RESULTS}) for search term: {search_term}")
                return APIResponse(items=[])
            
            response = self.session.get(
                f"{Config.BASE_URL}/search/companies",
                headers=self.headers,
                params=params
            )
            response.raise_for_status()
            return APIResponse(**response.json())
            
        except requests.exceptions.RequestException as e:
            self.logger.error(f"Error making request: {e}")
            return None
    
    def get_company_details(self, company_number: str) -> Optional[Dict[str, Any]]:
        """Get detailed information for a specific company."""
        try:
            self.rate_limiter.wait_if_needed()
            
            response = self.session.get(
                f"{Config.BASE_URL}/company/{company_number}",
                headers=self.headers
            )
            response.raise_for_status()
            return response.json()
            
        except requests.exceptions.RequestException as e:
            self.logger.error(f"Error fetching details for company {company_number}: {e}")
            return None

class InsuranceCompanyFinder:
    """Main class for finding and processing insurance companies."""
    
    def __init__(self, api: CompaniesHouseAPI, logger: logging.Logger):  # Add logger parameter
        self.api = api
        self.logger = logger  # Store logger as instance variable
        self.companies: List[CompanyData] = []
    
    def is_insurance_company(self, sic_codes: List[str]) -> bool:
        """Check if company is an insurance company based on SIC codes."""
        return any(code.startswith(prefix) for prefix in Config.INSURANCE_SIC_CODES 
                  for code in sic_codes if code)
    
    def process_company(self, company_number: str) -> None:
        """Process a single company."""
        if any(c.company_number == company_number for c in self.companies):
            return
            
        company_details = self.api.get_company_details(company_number)
        if not company_details:
            return
            
        sic_codes = company_details.get('sic_codes', [])
        if not self.is_insurance_company(sic_codes):
            return
            
        registered_office = company_details.get('registered_office_address', {})
        address_str = ', '.join(filter(None, [
            registered_office.get('address_line_1', ''),
            registered_office.get('address_line_2', ''),
            registered_office.get('locality', ''),
            registered_office.get('postal_code', '')
        ]))
        
        company_data = CompanyData(
            company_number=company_number,
            company_name=company_details.get('company_name', ''),
            company_status=company_details.get('company_status', ''),
            date_of_creation=company_details.get('date_of_creation', ''),
            registered_office_address=address_str,
            sic_codes=', '.join(sic_codes) if sic_codes else ''
        )
        
        self.companies.append(company_data)
        self.logger.info(f"Added: {company_data.company_name}")
    
    def search_all_companies(self) -> pd.DataFrame:
        """Search and process all insurance companies."""
        for search_term in Config.SEARCH_TERMS:
            self.logger.info(f"\nSearching for: {search_term}")
            start_index = 0
            
            while start_index < Config.MAX_RESULTS:
                results = self.api.search_companies(search_term, start_index)
                if not results or not results.items:
                    break
                
                self.logger.info(f"Processing {len(results.items)} results starting at index {start_index}")
                
                for company in results.items:
                    if company_number := company.get('company_number'):
                        self.process_company(company_number)
                
                if len(results.items) < Config.ITEMS_PER_PAGE:
                    break
                    
                start_index += Config.ITEMS_PER_PAGE
            
            self.logger.info(f"Completed search for term: {search_term}")
        
        # Convert to DataFrame
        df = pd.DataFrame([c.dict() for c in self.companies])
        return df.drop_duplicates(subset='company_number').sort_values('company_name')

def get_api_key() -> str:
    """Securely prompt for Companies House API key."""
    try:
        return getpass.getpass("Please enter your Companies House API key: ")
    except Exception as e:
        logger.error(f"Error getting API key: {e}")
        raise

def main() -> None:
    
    """Main function to run the insurance companies search and save results."""

    # Use the current date and time provided
    start_time = datetime.strptime("2025-01-15 12:38:15", "%Y-%m-%d %H:%M:%S")
    current_user = "scubamut"

    logger = setup_logging()
    
    logger.info(f"Script started by {current_user} at {start_time.strftime('%Y-%m-%d %H:%M:%S')} UTC")
    
    # Get API key securely
    api_key = get_api_key()
    
    # Create output directory
    Config.OUTPUT_DIR.mkdir(exist_ok=True)
    
    try:
        # Initialize API with logger
        api = CompaniesHouseAPI(api_key, logger)
        # Initialize finder with API and logger
        finder = InsuranceCompanyFinder(api, logger)
        insurance_companies_df = finder.search_all_companies()
        
        # Display results
        logger.info(f"\nFound {len(insurance_companies_df)} unique insurance companies")
        logger.info("\nFirst few companies:")
        logger.info(insurance_companies_df.head())
        
        # Save to CSV
        timestamp = start_time.strftime('%Y%m%d_%H%M%S')
        output_file = Config.OUTPUT_DIR / f"insurance_companies_{timestamp}_{current_user}.csv"
        insurance_companies_df.to_csv(output_file, index=False)
        logger.info(f"\nResults saved to {output_file}")
        
    except Exception as e:
        logger.error(f"An error occurred: {e}")
        raise
    finally:
        end_time = datetime.utcnow()
        logger.info(f"Script finished at {end_time.strftime('%Y-%m-%d %H:%M:%S')} UTC")
        logger.info(f"Total runtime: {end_time - start_time}")

if __name__ == "__main__":
    main()
# Out:
# 2025-01-15 14:41:56,195 - INFO - Script started by scubamut at 2025-01-15 12:38:15 UTC
# 2025-01-15 14:42:20,031 - INFO -
# Searching for: insurance company
# 2025-01-15 14:42:21,416 - INFO - Processing 100 results starting at index 0
# 2025-01-15 14:42:24,924 - INFO - Added: ADMIRAL INSURANCE COMPANY LIMITED
# 2025-01-15 14:42:25,512 - INFO - Added: AETNA INSURANCE COMPANY LIMITED
# 2025-01-15 14:42:26,501 - INFO - Added: AIOI NISSAY DOWA INSURANCE COMPANY OF EUROPE SE
# 2025-01-15 14:42:29,615 - INFO - Added: ANTARES INSURANCE COMPANY LIMITED
# 2025-01-15 14:42:33,082 - INFO - Added: AXA XL INSURANCE COMPANY UK LIMITED
# 2025-01-15 14:42:34,639 - INFO - Added: BAPTIST INSURANCE COMPANY PLC THE
# 2025-01-15 14:42:38,532 - INFO - Added: BIMEH IRAN INSURANCE COMPANY (U.K.) LIMITED
# 2025-01-15 14:42:40,323 - INFO - Added: BRITISH AVIATION INSURANCE COMPANY LIMITED
# 2025-01-15 14:42:41,418 - INFO - Processing 100 results starting at index 100
# 2025-01-15 14:42:41,806 - INFO - Added: BRITISH RESERVE INSURANCE COMPANY LIMITED
# 2025-01-15 14:42:46,819 - INFO - Added: CHUBB INSURANCE COMPANY OF EUROPE SE
# 2025-01-15 14:42:47,211 - INFO - Added: CHUBB INSURANCE SERVICE COMPANY LTD
# 2025-01-15 14:42:47,789 - INFO - Added: CHURCHILL INSURANCE COMPANY LIMITED
# 2025-01-15 14:42:49,317 - INFO - Added: CITY GENERAL INSURANCE COMPANY LIMITED
# 2025-01-15 14:42:50,686 - INFO - Added: CNA INSURANCE COMPANY LIMITED
# 2025-01-15 14:42
SURANCE COMPANY LIMITED
# 2025-01-15 14:47:31,184 - INFO - Added: BRAMPTON INSURANCE COMPANY LIMITED
# 2025-01-15 14:47:31,384 - INFO - Added: MARLON INSURANCE COMPANY LIMITED
# 2025-01-15 14:47:31,586 - INFO - Added: UNIONAMERICA INSURANCE COMPANY LIMITED
# 2025-01-15 14:47:31,792 - INFO - Added: R&Q BETA COMPANY PLC
# 2025-01-15 14:47:32,186 - INFO - Added: EXCESS INSURANCE COMPANY LIMITED
# 2025-01-15 14:47:33,170 - INFO - Added: CITY INTERNATIONAL INSURANCE COMPANY LIMITED
# 2025-01-15 14:47:33,369 - INFO - Added: TRAVEL AND GENERAL INSURANCE COMPANY P.L.C.
# 2025-01-15 14:47:33,771 - INFO - Added: R&Q GAMMA COMPANY LIMITED
# 2025-01-15 14:47:34,386 - INFO - Added: DOWA INSURANCE COMPANY (EUROPE) LIMITED
# 2025-01-15 14:47:34,591 - INFO - Added: CHUBB EUROPEAN GROUP PLC
# 2025-01-15 14:47:34,990 - INFO - Added: LONDON & LEITH INSURANCE COMPANY PLC
# 2025-01-15 14:47:35,196 - INFO - Added: MARINE SHIPPING MUTUAL INSURANCE COMPANY LIMITED
# 2025-01-15 14:47:35,394 - INFO - Added: PRINCIPLE INSURANCE COMPANY LIMITED
# 2025-01-15 14:47:36,396 - INFO - Added: MINSTER INSURANCE COMPANY LIMITED
# 2025-01-15 14:47:37,199 - INFO - Added: LIONCOVER INSURANCE COMPANY LIMITED
# 2025-01-15 14:47:37,399 - INFO - Added: CONTINGENCY INSURANCE COMPANY,LIMITED(THE)
# 2025-01-15 14:47:37,598 - INFO - Added: MALVERN INSURANCE COMPANY LIMITED
# 2025-01-15 14:47:37,804 - INFO - Added: PROGRESS INSURANCE COMPANY LIMITED
# 2025-01-15 14:47:38,001 - INFO - Added: THORNHILL & COMPANY (INSURANCE BROKERS) LIMITED
# 2025-01-15 14:47:38,398 - INFO - Added: CAVELL INSURANCE COMPANY LIMITED
# 2025-01-15 14:47:38,608 - INFO - Added: FIELDMILL INSURANCE COMPANY LIMITED
# 2025-01-15 14:47:38,808 - INFO - Added: LONGMYND INSURANCE COMPANY LIMITED
# 2025-01-15 14:47:39,010 - INFO - Added: INTERNATIONAL INSURANCE COMPANY OF HANNOVER PLC
# 2025-01-15 14:47:39,211 - INFO - Added: XL INSURANCE COMPANY PLC
# 2025-01-15 14:47:39,411 - INFO - Added: FUJI INTERNATIONAL INSURANCE COMPANY LIMITED
# 2025-01-15 14:47:40,406 - INFO - Added: PROTECTION LIFE COMPANY LIMITED
# 2025-01-15 14:47:41,009 - INFO - Added: GUILDHALL INSURANCE COMPANY LIMITED
# 2025-01-15 14:47:41,601 - INFO - Added: STILES & COMPANY INSURANCE SERVICES LIMITED
# 2025-01-15 14:47:42,000 - INFO - Added: AXERIA INSURANCE COMPANY LIMITED
# 2025-01-15 14:47:42,200 - INFO - Added: BHIB LIMITED
# 2025-01-15 14:47:43,001 - INFO - Added: UNDERSHAFT (BOILER) LIMITED
# 2025-01-15 14:47:43,204 - INFO - Added: UNDERSHAFT (HAMILTON) LIMITED
# 2025-01-15 14:47:43,410 - INFO - Added: TICOR TITLE INSURANCE COMPANY LIMITED
# 2025-01-15 14:47:43,609 - INFO - Added: ANSVAR INSURANCE COMPANY LIMITED
# 2025-01-15 14:47:45,843 - INFO - Processing 100 results starting at index 700
# 2025-01-15 14:47:46,457 - INFO - Added: AMLIN INSURANCE (UK) PUBLIC LIMITED COMPANY
# 2025-01-15 14:47:49,860 - INFO - Added: N I C L LIMITED
# 2025-01-15 14:47:51,054 - INFO - Added: FARES INSURANCE COMPANY SERVICES LTD
# 2025-01-15 14:47:51,253 - INFO - Added: AMTRUST EUROPE LIMITED
# 2025-01-15 14:47:53,668 - INFO - Added: CHINA TAIPING INSURANCE (UK) CO LTD
# 2025-01-15 14:47:54,065 - INFO - Added: ISLAND CAPITAL (EUROPE) LTD.
# 2025-01-15 14:47:54,463 - INFO - Added: AIG EUROPE LIMITED
SURANCE BROKERS LIMITED
# 2025-01-15 14:57:53,524 - INFO - Added: CHESTERFIELD INSURANCE BROKERS LIMITED
# 2025-01-15 14:57:53,734 - INFO - Added: CHESTERFIELDS INSURANCE SERVICES LIMITED
# 2025-01-15 14:57:53,945 - INFO - Completed search for term: insurance limited
# 2025-01-15 14:57:53,946 - INFO -
# Searching for: insurance ltd
# 2025-01-15 14:58:44,480 - INFO - Processing 100 results starting at index 0
# 2025-01-15 14:59:01,781 - INFO - Processing 100 results starting at index 100
# 2025-01-15 15:00:09,198 - INFO - Processing 100 results starting at index 200
# 2025-01-15 15:00:27,399 - INFO - Processing 100 results starting at index 300
# 2025-01-15 15:00:41,670 - INFO - Processing 100 results starting at index 400
# 2025-01-15 15:00:55,784 - INFO - Processing 100 results starting at index 500
# 2025-01-15 15:01:07,192 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:02:23,010 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:02:25,375 - INFO - Processing 100 results starting at index 600
# 2025-01-15 15:02:26,535 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:02:33,470 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:02:33,660 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:02:33,866 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:02:34,056 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:02:34,251 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:02:34,450 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:02:34,644 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:02:41,549 - INFO - Processing 100 results starting at index 700
# 2025-01-15 15:02:49,989 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:02:50,177 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:02:50,364 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:02:50,552 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:02:50,745 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:02:50,937 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:02:51,129 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:02:51,323 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:02:51,526 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:02:51,712 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:02:51,897 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:02:52,093 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:02:52,289 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:02:55,022 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:03:45,562 - INFO - Processing 100 results starting at index 800
# 2025-01-15 15:03:52,057 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:03:52,249 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:03:52,435 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:03:52,628 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:03:52,821 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:03:53,008 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:03:53,199 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:03:53,390 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:03:53,577 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:03:53,769 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:03:53,973 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:03:54,158 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:03:59,689 - INFO - Processing 100 results starting at index 900
# 2025-01-15 15:04:05,544 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:04:05,741 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:04:05,935 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:04:06,126 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:04:06,331 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:04:06,530 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:04:06,726 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:04:06,924 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:04:07,115 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:04:07,311 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:04:07,507 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:04:07,711 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:04:07,904 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:04:08,091 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:04:08,278 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:04:08,470 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:04:14,134 - INFO - Completed search for term: insurance ltd
# 2025-01-15 15:04:14,136 - INFO -
# Searching for: insurance plc
# 2025-01-15 15:04:14,459 - INFO - Processing 100 results starting at index 0
# 2025-01-15 15:04:19,197 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:05:09,444 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:05:09,641 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:05:09,838 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:05:10,032 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:05:18,682 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:05:18,871 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:05:19,055 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:05:19,244 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:05:19,428 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:05:19,614 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:05:19,802 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:05:19,994 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:05:20,192 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:05:20,385 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:05:20,575 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:05:20,761 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:05:22,480 - INFO - Processing 100 results starting at index 100
# 2025-01-15 15:05:30,457 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:05:30,651 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:05:30,840 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:05:31,029 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:05:31,214 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:05:31,411 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:05:31,604 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:05:31,796 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:05:31,988 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:05:32,172 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:05:32,372 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:05:32,562 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:05:32,751 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:05:32,938 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:05:33,128 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:05:42,231 - INFO - Processing 100 results starting at index 200
# 2025-01-15 15:05:58,567 - INFO - Processing 100 results starting at index 300
# 2025-01-15 15:06:08,513 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:07:23,561 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:07:25,507 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:07:25,706 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:07:25,904 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:07:26,099 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:07:26,294 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:07:26,493 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:07:26,691 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:07:27,879 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:07:28,536 - INFO - Processing 100 results starting at index 400
# 2025-01-15 15:07:28,539 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:07:35,302 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:07:42,844 - INFO - Processing 100 results starting at index 500
# 2025-01-15 15:07:53,194 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:07:55,914 - INFO - Rate limit reached. Current requests in window: 590
# ...
# 2025-01-15 15:36:06,007 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:36:06,201 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:36:06,389 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:36:06,584 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:36:06,781 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:36:06,975 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:36:07,170 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:36:07,362 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:36:07,553 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:36:07,738 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:36:07,930 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:36:08,137 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:36:08,333 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:36:08,524 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:36:08,716 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:36:08,912 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:36:09,104 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:36:09,549 - INFO - Processing 100 results starting at index 200
# 2025-01-15 15:36:09,559 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:36:13,592 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:26,470 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:27,617 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:27,808 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:28,004 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:28,203 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:28,403 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:28,596 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:28,789 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:28,986 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:29,180 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:29,376 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:29,571 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:30,772 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:30,968 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:31,165 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:31,359 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:31,555 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:31,742 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:31,930 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:32,128 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:32,321 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:32,515 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:32,705 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:32,899 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:33,089 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:33,276 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:33,467 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:33,664 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:33,851 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:34,036 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:34,225 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:34,417 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:34,606 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:34,792 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:34,976 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:35,169 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:35,353 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:35,538 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:35,728 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:35,922 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:36,116 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:36,307 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:36,501 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:36,689 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:36,875 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:37,068 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:37,261 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:37,455 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:37,648 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:38,842 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:39,031 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:39,223 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:39,413 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:39,605 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:39,798 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:39,985 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:40,178 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:40,367 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:40,558 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:40,749 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:40,936 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:41,123 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:41,323 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:41,513 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:41,710 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:41,908 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:42,105 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:42,754 - INFO - Processing 100 results starting at index 300
# 2025-01-15 15:37:42,757 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:53,945 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:57,022 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:37:59,350 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:38:49,933 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:38:52,792 - INFO - Processing 100 results starting at index 400
# 2025-01-15 15:39:11,382 - INFO - Processing 100 results starting at index 500
# 2025-01-15 15:39:11,762 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:39:14,069 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:39:23,326 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:40:13,149 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:40:19,188 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:40:23,052 - INFO - Processing 100 results starting at index 600
# 2025-01-15 15:40:34,047 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:40:34,251 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:40:34,453 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:40:34,653 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:40:34,854 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:40:35,057 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:40:35,250 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:40:35,446 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:40:35,641 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:40:35,840 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:40:36,042 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:40:36,242 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:40:36,442 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:40:36,644 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:40:36,846 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:40:37,045 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:40:37,242 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:40:37,440 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:40:38,432 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:40:42,722 - INFO - Processing 100 results starting at index 700
# 2025-01-15 15:40:42,729 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:40:44,336 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:41:04,337 - INFO - Processing 100 results starting at index 800
# 2025-01-15 15:41:04,941 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:41:05,147 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:41:05,347 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:41:05,548 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:41:05,747 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:41:05,945 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:41:06,147 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:41:06,349 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:41:06,546 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:41:06,749 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:41:06,952 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:41:07,157 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:41:07,357 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:41:07,561 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:41:09,555 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:41:14,733 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:42:26,601 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:42:26,794 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:42:26,985 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:42:27,180 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:42:27,374 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:42:27,571 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:42:27,765 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:42:27,960 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:42:28,152 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:42:28,342 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:42:28,531 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:42:28,720 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:42:28,913 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:42:29,114 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:42:29,313 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:42:29,517 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:42:29,715 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:42:30,914 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:42:31,130 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:42:31,329 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:42:31,531 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:42:31,734 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:42:31,925 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:42:32,114 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:42:32,314 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:42:32,511 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:42:32,707 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:42:37,265 - INFO - Processing 100 results starting at index 900
# 2025-01-15 15:42:38,420 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:42:54,425 - INFO - Rate limit reached. Current requests in window: 590
# 2025-01-15 15:42:55,811 - INFO - Completed search for term: assurance plc
# 2025-01-15 15:42:55,902 - INFO -
# Found 484 unique insurance companies
# 2025-01-15 15:42:55,903 - INFO -
# First few companies:
# 2025-01-15 15:42:55,905 - INFO -     company_number                               company_name company_status  \
# 149       06436514           A & G INSURANCE SERVICES LIMITED         active
# 200       06428843              A M S INSURANCE SOLUTIONS LTD         active
# 211       04754078  A ONE PROPERTY INSURANCE SERVICES LIMITED         active
# 150       02657979              A+ INSURANCE SERVICES LIMITED    liquidation
# 151       02706320          A.B.A. INSURANCE SERVICES LIMITED         active
#
#     date_of_creation                          registered_office_address  \
# 149       2007-11-26  1 Unicorn Parade, Unicorn Hill, Redditch, B97 4QR
# 200       2007-11-16    2 Minster Court, Mincing Lane, London, EC3R 7PD
# 211       2003-05-06  The Old Exchange, 521 Wimborne Road East Fernd...
# 150       1991-10-28               28 Castle Street, Hertford, SG14 1HH
# 151       1992-04-13             1 Great Tower Street, London, EC3R 5AA
#
#         sic_codes
# 149         65120
# 200         65120
# 211         65120
# 150         65120
# 151  65120, 66220
# 2025-01-15 15:42:55,962 - INFO -
# Results saved to insurance_companies_data/insurance_companies_20250115_123815_scubamut.csv
# 2025-01-15 15:42:55,963 - INFO - Script finished at 2025-01-15 13:42:55 UTC
# 2025-01-15 15:42:55,965 - INFO - Total runtime: 1:04:40.963791

# %%
main().outfile
# Out:
# 2025-01-15 16:04:26,559 - INFO - Script started by scubamut at 2025-01-15 12:38:15 UTC
# 2025-01-15 16:04:37,412 - INFO -
# Searching for: insurance company
# 2025-01-15 16:04:38,186 - ERROR - Error making request: 400 Client Error: Bad Request for url: https://api.companieshouse.gov.uk/search/companies?q=insurance+company&items_per_page=100&start_index=0&company_status=active
# 2025-01-15 16:04:38,187 - INFO - Completed search for term: insurance company
# 2025-01-15 16:04:38,188 - INFO -
# Searching for: insurance limited
# 2025-01-15 16:04:38,377 - ERROR - Error making request: 400 Client Error: Bad Request for url: https://api.companieshouse.gov.uk/search/companies?q=insurance+limited&items_per_page=100&start_index=0&company_status=active
# 2025-01-15 16:04:38,378 - INFO - Completed search for term: insurance limited
# 2025-01-15 16:04:38,379 - INFO -
# Searching for: insurance ltd
# 2025-01-15 16:04:38,577 - ERROR - Error making request: 400 Client Error: Bad Request for url: https://api.companieshouse.gov.uk/search/companies?q=insurance+ltd&items_per_page=100&start_index=0&company_status=active
# 2025-01-15 16:04:38,578 - INFO - Completed search for term: insurance ltd
# 2025-01-15 16:04:38,579 - INFO -
# Searching for: insurance plc
# 2025-01-15 16:04:38,767 - ERROR - Error making request: 400 Client Error: Bad Request for url: https://api.companieshouse.gov.uk/search/companies?q=insurance+plc&items_per_page=100&start_index=0&company_status=active
# 2025-01-15 16:04:38,769 - INFO - Completed search for term: insurance plc
# 2025-01-15 16:04:38,771 - INFO -
# Searching for: assurance company
# 2025-01-15 16:04:38,964 - ERROR - Error making request: 400 Client Error: Bad Request for url: https://api.companieshouse.gov.uk/search/companies?q=assurance+company&items_per_page=100&start_index=0&company_status=active
# 2025-01-15 16:04:38,965 - INFO - Completed search for term: assurance company
# 2025-01-15 16:04:38,966 - INFO -
# Searching for: assurance limited
# 2025-01-15 16:04:39,171 - ERROR - Error making request: 400 Client Error: Bad Request for url: https://api.companieshouse.gov.uk/search/companies?q=assurance+limited&items_per_page=100&start_index=0&company_status=active
# 2025-01-15 16:04:39,172 - INFO - Completed search for term: assurance limited
# 2025-01-15 16:04:39,173 - INFO -
# Searching for: assurance ltd
# 2025-01-15 16:04:39,367 - ERROR - Error making request: 400 Client Error: Bad Request for url: https://api.companieshouse.gov.uk/search/companies?q=assurance+ltd&items_per_page=100&start_index=0&company_status=active
# 2025-01-15 16:04:39,369 - INFO - Completed search for term: assurance ltd
# 2025-01-15 16:04:39,370 - INFO -
# Searching for: assurance plc
# 2025-01-15 16:04:39,562 - ERROR - Error making request: 400 Client Error: Bad Request for url: https://api.companieshouse.gov.uk/search/companies?q=assurance+plc&items_per_page=100&start_index=0&company_status=active
# 2025-01-15 16:04:39,564 - INFO - Completed search for term: assurance plc
# 2025-01-15 16:04:39,569 - ERROR - An error occurred: 'company_name'
# 2025-01-15 16:04:39,571 - INFO - Script finished at 2025-01-15 14:04:39 UTC
# 2025-01-15 16:04:39,572 - INFO - Total runtime: 1:26:24.570958
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1555953/565735301.py in ?()
# ----> 1 main().outfile
#
# /tmp/ipykernel_1555953/3954307981.py in ?()
#     312         raise
#     313     finally:
#     314         end_time = datetime.utcnow()
#     315         logger.info(f"Script finished at {end_time.strftime('%Y-%m-%d %H:%M:%S')} UTC")
# --> 316         logger.info(f"Total runtime: {end_time - start_time}")
#
# /tmp/ipykernel_1555953/3954307981.py in ?(self)
#     260             self.logger.info(f"Completed search for term: {search_term}")
#     261
#     262         # Convert to DataFrame
#     263         df = pd.DataFrame([c.dict() for c in self.companies])
# --> 264         return df.drop_duplicates(subset='company_number').sort_values('company_name')
#
# ~/.local/lib/python3.10/site-packages/pandas/core/frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    7185             )
#    7186         elif len(by):
#    7187             # len(by) == 1
#    7188
# -> 7189             k = self._get_label_or_level_values(by[0], axis=axis)
#    7190
#    7191             # need to rewrap column in Series to apply key function
#    7192             if key is not None:
#
# ~/.local/lib/python3.10/site-packages/pandas/core/generic.py in ?(self, key, axis)
#    1907             values = self.xs(key, axis=other_axes[0])._values
#    1908         elif self._is_level_reference(key, axis=axis):
#    1909             values = self.axes[axis].get_level_values(key)._values
#    1910         else:
# -> 1911             raise KeyError(key)
#    1912
#    1913         # Check for duplicates
#    1914         if values.ndim > 1:
#
# KeyError: 'company_name'
